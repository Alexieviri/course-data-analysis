# %% [markdown]
# Лабораторная работа № 2: **Pandas** <br>
# Выполнил: **Стадников Александр, гр.6135**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ------
# ------
# ### 1. Считать в pandas DataFrame любой источник данных:
# <br>
# любой CSV, JSON, Excel-файл, HTML-таблицу, данные из любой СУБД куда у вас есть доступ и т.п. Также можно сконвертировать в dataframe любой из встроенных датасетов sklearn: (см. инструкцию) Одним словом загружаете данные откуда угодно, куда можете дотянуться. Главное условие к датасету, который вы загружаете — там должны быть числовые колонки (по сути численные признаки).

# %% [markdown]
# **Исходные данные:** https://www.kaggle.com/deepu1109/star-dataset <br><br>
# Этот датасет содержит характеристики звёзд. <br><br>
# P.S.: <br>
# Цель создания набора данных - доказать, что звезды следуют определенному графику в небесном пространстве, специально называемая диаграммой Герцшпрунга-Рассела или просто HR-диаграммой так что мы можем классифицировать звезды, нанося их характеристики на основе этого графика. <br><br>
# **Датасет: классификация звёзд**
# <br>
# - **Temperature** - температуры в Кельвинах
# - **L** - Relative Luminosity (относительная яркость)
# - **R** - Relative Radius (относительный радиус)
# - **A_M** - Absolute Magnitude (абсолютная величина) - подразумевается "Абсолютная звёздная величина" или блеск объекта
# - **Color** - цвет
# - **Spectral_Class** - спектральный класс
# - **Type** - тип от 0 до 5
# -- **Brown Dwarf** -> Star Type = 0
# -- **Red Dwarf** -> Star Type = 1
# -- **White Dwarf**-> Star Type = 2
# -- **Main Sequence** -> Star Type = 3
# -- **Supergiant** -> Star Type = 4
# -- **Hypergiant** -> Star Type = 5

# %%
df = pd.read_csv(r'Stars.csv') # Датасет классифицированных звёзд
df.head(3)
# Out:
#    Temperature       L       R    A_M Color Spectral_Class  Type
# 0         3068  0.0024  0.1700  16.12   Red              M     0
# 1         3042  0.0005  0.1542  16.60   Red              M     0
# 2         2600  0.0003  0.1020  18.70   Red              M     0

# %% [markdown]
# ------
# ------
# ### 2. Совершаете с датафреймом следующие операции:
# ------
# ------

# %% [markdown]
# #### 2.1 .head()

# %%
df.head()
# Out:
#    Temperature         L       R    A_M Color Spectral_Class  Type
# 0         3068  0.002400  0.1700  16.12   Red              M     0
# 1         3042  0.000500  0.1542  16.60   Red              M     0
# 2         2600  0.000300  0.1020  18.70   Red              M     0
# 3         2800  0.000200  0.1600  16.65   Red              M     0
# 4         1939  0.000138  0.1030  20.06   Red              M     0

# %% [markdown]
# #### 2.2 .describe()

# %%
df.describe()
# Out:
#         Temperature              L            R         A_M        Type
# count    240.000000     240.000000   240.000000  240.000000  240.000000
# mean   10497.462500  107188.361635   237.157781    4.382396    2.500000
# std     9552.425037  179432.244940   517.155763   10.532512    1.711394
# min     1939.000000       0.000080     0.008400  -11.920000    0.000000
# 25%     3344.250000       0.000865     0.102750   -6.232500    1.000000
# 50%     5776.000000       0.070500     0.762500    8.313000    2.500000
# 75%    15055.500000  198050.000000    42.750000   13.697500    4.000000
# max    40000.000000  849420.000000  1948.500000   20.060000    5.000000

# %% [markdown]
# #### 2.3 считайте значение конкретной ячейки (с конкретным индексом из конкретной колонки)

# %%
df.iloc[0,1]
# Out:
# 0.0024

# %% [markdown]
# #### 2.4 фильтрация строк по диапазону индекса

# %%
df[df['Temperature']>4000] # Температура больше 4000 K
# Out:
#      Temperature             L           R    A_M       Color Spectral_Class  \
# 20         25000       0.05600     0.00840  10.58  Blue White              B
# 21          7740       0.00049     0.01234  14.02       White              A
# 22          7220       0.00017     0.01100  14.23       White              F
# 23          8500       0.00050     0.01000  14.50       White              A
# 24         16500       0.01300     0.01400  11.89  Blue White              B
# ..           ...           ...         ...    ...         ...            ...
# 235        38940  374830.00000  1356.00000  -9.93        Blue              O
# 236        30839  834042.00000  1194.00000 -10.63        Blue              O
# 237         8829  537493.00000  1423.00000 -10.73       White              A
# 238         9235  404940.00000  1112.00000 -11.23       White              A
# 239        37882  294903.00000  1783.00000  -7.80        Blue              O
#
#      Type
# 20      2
# 21      2
# ...

# %% [markdown]
# #### 2.5 фильтрация набора данных по какому-либо условию

# %%
df.isna().sum() # Посмотрим есть ли неопределнные ячейки
# Out:
# Temperature       0
# L                 0
# R                 0
# A_M               0
# Color             0
# Spectral_Class    0
# Type              0
# dtype: int64

# %% [markdown]
# #### 2.6 работа с пропущенными значениями (если они есть): удаление строк с пропущенными значениями, заполнение пропущенных значений средним значением по колонке. Если пропущенных значений нет — намеренно их "генерируете", прибивая какие-то куски данных в np.nan

# %%
for _ in range(0, 25):
    df.iloc[np.random.randint(0,df.shape[0]),0] = np.NaN # Добавим неизветсных в данные в случайную строку в колонку Temperature

# %%
df.isna().sum() # Добавилось
# Out:
# Temperature       20
# L                  0
# R                  0
# A_M                0
# Color              0
# Spectral_Class     0
# Type               0
# dtype: int64

# %%
df['Temperature'] = df['Temperature'].fillna(value=df['Temperature'].mean()) # Заменим неизвестные средним значением этой колонки

# %%
df.isna().sum() # Проверим что теперь снова все чисто
# Out:
# Temperature       0
# L                 0
# R                 0
# A_M               0
# Color             0
# Spectral_Class    0
# Type              0
# dtype: int64

# %% [markdown]
# #### 2.7 создание нового поля вычисленного на основе значений других полей:
# - через выражение на базе имеющихся колонок,
# - через DataFrame.apply
# - через Series.apply

# %%
df['TemperatureC'] = df['Temperature'] + 273.15 # Температура в градусах Цельсия
df.head()
# Out:
#     Temperature         L       R    A_M Color Spectral_Class  Type  \
# 0  10820.436364  0.002400  0.1700  16.12   Red              M     0
# 1  10820.436364  0.000500  0.1542  16.60   Red              M     0
# 2   2600.000000  0.000300  0.1020  18.70   Red              M     0
# 3   2800.000000  0.000200  0.1600  16.65   Red              M     0
# 4   1939.000000  0.000138  0.1030  20.06   Red              M     0
#
#    TemperatureC
# 0  11093.586364
# 1  11093.586364
# 2   2873.150000
# 3   3073.150000
# 4   2212.150000

# %%
df['A_M_type'] = df['A_M'].apply(lambda x: 'small' if x < 4 else 'big' ) # Применение к PandasSeries
df.head()
# Out:
#     Temperature         L       R    A_M Color Spectral_Class  Type  \
# 0  10820.436364  0.002400  0.1700  16.12   Red              M     0
# 1  10820.436364  0.000500  0.1542  16.60   Red              M     0
# 2   2600.000000  0.000300  0.1020  18.70   Red              M     0
# 3   2800.000000  0.000200  0.1600  16.65   Red              M     0
# 4   1939.000000  0.000138  0.1030  20.06   Red              M     0
#
#    TemperatureC A_M_type
# 0  11093.586364      big
# 1  11093.586364      big
# 2   2873.150000      big
# 3   3073.150000      big
# 4   2212.150000      big

# %%
df['TemperatureF']=df.apply(lambda x: x['TemperatureC']*9/5+32, axis=1) # Применение к PandasFrame
df.head()
# Out:
#     Temperature         L       R    A_M Color Spectral_Class  Type  \
# 0  10820.436364  0.002400  0.1700  16.12   Red              M     0
# 1  10820.436364  0.000500  0.1542  16.60   Red              M     0
# 2   2600.000000  0.000300  0.1020  18.70   Red              M     0
# 3   2800.000000  0.000200  0.1600  16.65   Red              M     0
# 4   1939.000000  0.000138  0.1030  20.06   Red              M     0
#
#    TemperatureC A_M_type  TemperatureF
# 0  11093.586364      big  20000.455455
# 1  11093.586364      big  20000.455455
# 2   2873.150000      big   5203.670000
# 3   3073.150000      big   5563.670000
# 4   2212.150000      big   4013.870000

# %% [markdown]
# #### 2.8 сортировка по какому-либо из полей

# %%
df.sort_values(by='Temperature')
# Out:
#      Temperature              L         R    A_M Color Spectral_Class  Type  \
# 4         1939.0       0.000138     0.103  20.06   Red              M     0
# 2         2600.0       0.000300     0.102  18.70   Red              M     0
# 7         2600.0       0.000400     0.096  17.40   Red              M     0
# 78        2621.0       0.000600     0.098  12.81   Red              M     1
# 6         2637.0       0.000730     0.127  17.22   Red              M     0
# ..           ...            ...       ...    ...   ...            ...   ...
# 239      37882.0  294903.000000  1783.000  -7.80  Blue              O     5
# 231      38234.0  272830.000000  1356.000  -9.29  Blue              O     5
# 235      38940.0  374830.000000  1356.000  -9.93  Blue              O     5
# 30       39000.0  204000.000000    10.600  -4.70  Blue              O     3
# 101      40000.0  813000.000000    14.000  -6.23  Blue              O     4
#
#      TemperatureC A_M_type  TemperatureF
# ...

# %% [markdown]
# #### 2.9 вычислить несколько статистик по колонкам (используйте встроенные агрегатные функции — любые на выбор)

# %%
statistics = ['mean', 'max', 'min', 'std', 'median']
columns = list(df)
for col in columns[0:4]:
    print(f'for {col}')
    for stat in statistics:
        print(f' {stat} = {df[col].agg(stat)} ')
# Out:
# for Temperature
#  mean = 10820.436363636365
#  max = 40000.0
#  min = 1939.0
#  std = 9328.421622940929
#  median = 8151.0
# for L
#  mean = 107188.36163460833
#  max = 849420.0
#  min = 8e-05
#  std = 179432.2449402145
#  median = 0.07050000000000001
# for R
#  mean = 237.157781375
#  max = 1948.5
#  min = 0.0084
#  std = 517.1557634028478
#  median = 0.7625
# for A_M
#  mean = 4.382395833333334
#  max = 20.06
#  min = -11.92
#  std = 10.53251235061617
#  median = 8.312999999999999

# %% [markdown]
# #### 2.10 По какому-либо полю / набору полей смотрим число значений с помощью .value_counts()

# %%
df['Color'].value_counts()
# Out:
# Red                   112
# Blue                   56
# Blue-white             26
# Blue White             10
# yellow-white            8
# White                   7
# Blue white              4
# Yellowish White         3
# white                   3
# Whitish                 2
# yellowish               2
# Orange                  2
# Orange-Red              1
# White-Yellow            1
# Yellowish               1
# Pale yellow orange      1
# Blue-White              1
# Name: Color, dtype: int64

# %% [markdown]
# #### 2.11 Если значений немного — вывод уникальных значений какой-либо колонки через .unique()

# %%
pd.unique(df['Color'])
# Out:
# array(['Red', 'Blue White', 'White', 'Yellowish White', 'Blue white',
#        'Pale yellow orange', 'Blue', 'Blue-white', 'Whitish',
#        'yellow-white', 'Orange', 'White-Yellow', 'white', 'yellowish',
#        'Yellowish', 'Orange-Red', 'Blue-White'], dtype=object)

# %% [markdown]
# #### 2.12 Удалите текущий индекс и создайте новый индекс на базе новой колонки, которая для этого лучше всего подходит

# %%
df_new_index = df.set_index('L')
df_new_index
# Out:
#                 Temperature          R    A_M  Color Spectral_Class  Type  \
# L
# 0.002400       10820.436364     0.1700  16.12    Red              M     0
# 0.000500       10820.436364     0.1542  16.60    Red              M     0
# 0.000300        2600.000000     0.1020  18.70    Red              M     0
# 0.000200        2800.000000     0.1600  16.65    Red              M     0
# 0.000138        1939.000000     0.1030  20.06    Red              M     0
# ...                     ...        ...    ...    ...            ...   ...
# 374830.000000  38940.000000  1356.0000  -9.93   Blue              O     5
# 834042.000000  30839.000000  1194.0000 -10.63   Blue              O     5
# 537493.000000   8829.000000  1423.0000 -10.73  White              A     5
# 404940.000000   9235.000000  1112.0000 -11.23  White              A     5
# 294903.000000  37882.000000  1783.0000  -7.80   Blue              O     5
#
#                TemperatureC A_M_type  TemperatureF
# L
# ...

# %% [markdown]
# --------
# --------
# ### 3. Продемонстрировать работу .groupby, на основе группировок в groupby вычисляете агрегатные функции по одной или нескольким колонкам.
# -------
# -------

# %%
# сколько звёзд каждого цвета в каждом спектральном классе
df.groupby(['Spectral_Class', 'Color'])['Color'].count()
# Out:
# Spectral_Class  Color
# A               Blue White              1
#                 Blue white              2
#                 Blue-White              1
#                 Blue-white              8
#                 White                   5
#                 Whitish                 1
#                 white                   1
# B               Blue                   16
#                 Blue White              9
#                 Blue white              2
#                 Blue-white             18
#                 Whitish                 1
# F               Pale yellow orange      1
#                 White                   2
#                 White-Yellow            1
#                 Yellowish White         3
#                 white                   2
#                 yellow-white            8
# G               Red                     1
# K               Orange                  1
#                 Orange-Red              1
#                 Red                     1
# ...

# %% [markdown]
# ------
# ------
# ### 4. Решейпинг данных 1Dto2D с помощью .pivot (можно подать на вход результаты агрегатов, полученных ранее через .groupby (сгруппировать по двум полям), либо прекрасно заходит сюда данные из SQL сгруппированные предварительно по 2-м полям)
# ------
# ------

# %%
# средняя температура для каждой комбинации Color * Spectral_Class

df_grp = df.groupby(['Color', 'Spectral_Class'])['Temperature'].mean().reset_index()
df_grp.pivot(index = 'Color', columns = 'Spectral_Class' )
df_grp
# Out:
#                  Color Spectral_Class   Temperature
# 0                 Blue              B  20414.027273
# 1                 Blue              O  22294.075000
# 2           Blue White              A   9675.000000
# 3           Blue White              B  14481.604040
# 4           Blue white              A   9695.218182
# 5           Blue white              B  12406.000000
# 6           Blue-White              A   8945.000000
# 7           Blue-white              A  11325.554545
# 8           Blue-white              B  21241.357576
# 9               Orange              K  10820.436364
# 10              Orange              M   3749.000000
# 11          Orange-Red              K   5112.000000
# 12  Pale yellow orange              F   7230.000000
# 13                 Red              G   6850.000000
# 14                 Red              K   4015.000000
# 15                 Red              M   4081.938512
# 16               White              A   8405.400000
# ...

# %% [markdown]
# -----
# -----
# ### 5. Решейпинг 1Dto2D данных соединённый с группировкой / агрегацией (одним словом — сводная таблица): .pivot_table. Группируем только по категориальным полям или числовым, если уверены, что значений немного! Если значений много, можете вначале из загрубить (см. (2.7.) либо (7))
# -----
# -----

# %%
# средний радиус каждого типа звёзд определённого спектра
# без NaN подобную таблицу составить не получится, т.к. это особенность датасета
df_grp1 = df.pivot_table(index=['Type'], columns=['Spectral_Class'], values='R', aggfunc='mean')
df_grp1[df_grp1.notnull() == True]
# Out:
# Spectral_Class            A            B         F       G          K  \
# Type
# 0                       NaN          NaN       NaN     NaN        NaN
# 1                       NaN          NaN       NaN     NaN        NaN
# 2                  0.010001     0.010935  0.010742     NaN        NaN
# 3                  4.662000     5.951000  1.159500     NaN     0.9165
# 4                       NaN    19.000000       NaN     NaN        NaN
# 5               1267.500000  1311.057143       NaN  1467.0  1424.5000
#
# Spectral_Class            M            O
# Type
# 0                  0.110015          NaN
# 1                  0.348145          NaN
# 2                       NaN          NaN
# 3                       NaN     8.057400
# 4                 46.555556    54.793103
# 5               1362.045455  1447.083333

# %% [markdown]
# -----
# -----
# ### 6. Посчитать квантили распределения какого-либо вещественного признака (с помощью numpy.quantile или numpy.percentile)
# ------
# ------

# %%
np.quantile(df['L'], 0.99)
# Out:
# 801662.6999999996

# %% [markdown]
# ------
# ------
# ### 7. Посчитать (в виде текста) гистограмму какого-либо вещественного признака (с помощью numpy.histogram). Значения гистограммы можете использовать как вариант в качестве загрубленного числового признака для заданий (4) или (5).
# ------
# ------

# %%
np.histogram(df['Temperature'], bins = 10)
# Out:
# (array([105,  27,  43,  16,  11,  14,   7,   4,   7,   6], dtype=int64),
#  array([ 1939. ,  5745.1,  9551.2, 13357.3, 17163.4, 20969.5, 24775.6,
#         28581.7, 32387.8, 36193.9, 40000. ]))

# %% [markdown]
# ------
# ------
# ### 8. Получить DataFrame с MultiIndex любым способом: через конструктор (в документации увидите множество видов конструкторов для создания MultiIndex с нуля), через read_sql / read_csv / read_excel, read_*, через pivot_table, через groupby или иными способами.
#
# - Переставить местами уровни индекса
# - Транспонировать таблицу (или создать новую другую) с MultiIndex
# - Удалить один из уровней индекса или добавить новый уровень индекса (можно инициализированный константой) — посмотрите сами в документации как это делать
# ------
# ------

# %%
df2 = df.pivot_table(index = ['Spectral_Class', 'Type'], columns = 'Color', values = 'Temperature').fillna(0).astype(int)
df2
# Out:
# Color                 Blue  Blue White  Blue white  Blue-White  Blue-white  \
# Spectral_Class Type
# A              2         0        9675        9695           0           0
#                3         0           0           0        8945       11325
#                5         0           0           0           0           0
# B              2     17967       14481       12406           0           0
#                3         0           0           0           0       21747
#                4     33525           0           0           0           0
#                5     26000           0           0           0       20229
# F              2         0           0           0           0           0
#                3         0           0           0           0           0
# G              5         0           0           0           0           0
# K              3         0           0           0           0           0
# ...

# %% [markdown]
# #### 8.1. Переставить местами уровни индекса

# %%
df2.swaplevel( i = 0, j = 1, axis = 0 ).sort_index()
# Out:
# Color                 Blue  Blue White  Blue white  Blue-White  Blue-white  \
# Type Spectral_Class
# 0    M                   0           0           0           0           0
# 1    M                   0           0           0           0           0
# 2    A                   0        9675        9695           0           0
#      B               17967       14481       12406           0           0
#      F                   0           0           0           0           0
# 3    A                   0           0           0        8945       11325
#      B                   0           0           0           0       21747
#      F                   0           0           0           0           0
#      K                   0           0           0           0           0
#      O               35911           0           0           0           0
# 4    B               33525           0           0           0           0
# ...

# %% [markdown]
# #### 8.2. Транспонировать таблицу (или создать новую другую) с MultiIndex

# %%
df2.transpose()
# Out:
# Spectral_Class         A                   B                           F  \
# Type                   2      3     5      2      3      4      5      2
# Color
# Blue                   0      0     0  17967      0  33525  26000      0
# Blue White          9675      0     0  14481      0      0      0      0
# Blue white          9695      0     0  12406      0      0      0      0
# Blue-White             0   8945     0      0      0      0      0      0
# Blue-white             0  11325     0      0  21747      0  20229      0
# Orange                 0      0     0      0      0      0      0      0
# Orange-Red             0      0     0      0      0      0      0      0
# Pale yellow orange     0      0     0      0      0      0      0   7230
# Red                    0      0     0      0      0      0      0      0
# White               7987      0  9032      0      0      0      0   8897
# White-Yellow           0      0     0      0      0      0      0   7100
# ...

# %% [markdown]
# #### 8.3. Удалить один из уровней индекса или добавить новый уровень индекса (можно инициализированный константой) — посмотрите сами в документации как это делать

# %%
df2.droplevel(1)
# Out:
# Color            Blue  Blue White  Blue white  Blue-White  Blue-white  Orange  \
# Spectral_Class
# A                   0        9675        9695           0           0       0
# A                   0           0           0        8945       11325       0
# A                   0           0           0           0           0       0
# B               17967       14481       12406           0           0       0
# B                   0           0           0           0       21747       0
# B               33525           0           0           0           0       0
# B               26000           0           0           0       20229       0
# F                   0           0           0           0           0       0
# F                   0           0           0           0           0       0
# G                   0           0           0           0           0       0
# K                   0           0           0           0           0       0
# ...

# %% [markdown]
# -----
# -----
# ### 9. Продемонстировать работу .merge
# -----
# -----

# %%
df_new = pd.DataFrame({'Temperature': df.Temperature, 'R': np.random.rand(df.Temperature.count())})
df_new
# Out:
#       Temperature         R
# 0    10820.436364  0.082886
# 1    10820.436364  0.358579
# 2     2600.000000  0.038149
# 3     2800.000000  0.361187
# 4     1939.000000  0.977493
# ..            ...       ...
# 235  38940.000000  0.396488
# 236  30839.000000  0.804957
# 237   8829.000000  0.256631
# 238   9235.000000  0.402483
# 239  37882.000000  0.457405
#
# [240 rows x 2 columns]

# %%
df_merge = df.merge(df_new, left_on='Temperature', right_on='Temperature') 
df_merge
# Out:
#       Temperature            L      R_x    A_M  Color Spectral_Class  Type  \
# 0    10820.436364       0.0024     0.17  16.12    Red              M     0
# 1    10820.436364       0.0024     0.17  16.12    Red              M     0
# 2    10820.436364       0.0024     0.17  16.12    Red              M     0
# 3    10820.436364       0.0024     0.17  16.12    Red              M     0
# 4    10820.436364       0.0024     0.17  16.12    Red              M     0
# ..            ...          ...      ...    ...    ...            ...   ...
# 639  38940.000000  374830.0000  1356.00  -9.93   Blue              O     5
# 640  30839.000000  834042.0000  1194.00 -10.63   Blue              O     5
# 641   8829.000000  537493.0000  1423.00 -10.73  White              A     5
# 642   9235.000000  404940.0000  1112.00 -11.23  White              A     5
# 643  37882.000000  294903.0000  1783.00  -7.80   Blue              O     5
#
#      TemperatureC A_M_type  TemperatureF       R_y
# ...

# %% [markdown]
# -----
# -----
# ### 10. Продемонстрировать работу с .concat или append
# -----
# -----

# %%
df_p1 = df[:5]
df_p2 = df[5:10]
df_3 = pd.concat([df_p1,df_p2])
df_3
# Out:
#     Temperature         L       R    A_M Color Spectral_Class  Type  \
# 0  10820.436364  0.002400  0.1700  16.12   Red              M     0
# 1  10820.436364  0.000500  0.1542  16.60   Red              M     0
# 2   2600.000000  0.000300  0.1020  18.70   Red              M     0
# 3   2800.000000  0.000200  0.1600  16.65   Red              M     0
# 4   1939.000000  0.000138  0.1030  20.06   Red              M     0
# 5   2840.000000  0.000650  0.1100  16.98   Red              M     0
# 6   2637.000000  0.000730  0.1270  17.22   Red              M     0
# 7   2600.000000  0.000400  0.0960  17.40   Red              M     0
# 8   2650.000000  0.000690  0.1100  17.45   Red              M     0
# 9   2700.000000  0.000180  0.1300  16.05   Red              M     0
#
#    TemperatureC A_M_type  TemperatureF
# 0  11093.586364      big  20000.455455
# 1  11093.586364      big  20000.455455
# 2   2873.150000      big   5203.670000
# 3   3073.150000      big   5563.670000
# ...

# %% [markdown]
# ------
# ------
# ### 11. Проитерировать dataframe построчно .iterrows() и что-то "полезное" сделайте внутри цикла
# ------
# ------

# %%
# используем iterrows для получения каждого элемента строк в датафрейме.
for i  in df_3.iterrows():
    print(i)
# Out:
# (0, Temperature       10820.4
# L                  0.0024
# R                    0.17
# A_M                 16.12
# Color                 Red
# Spectral_Class          M
# Type                    0
# TemperatureC      11093.6
# A_M_type              big
# TemperatureF      20000.5
# Name: 0, dtype: object)
# (1, Temperature       10820.4
# L                  0.0005
# R                  0.1542
# A_M                  16.6
# Color                 Red
# Spectral_Class          M
# Type                    0
# TemperatureC      11093.6
# A_M_type              big
# TemperatureF      20000.5
# Name: 1, dtype: object)
# (2, Temperature          2600
# L                  0.0003
# R                   0.102
# A_M                  18.7
# Color                 Red
# Spectral_Class          M
# Type                    0
# TemperatureC      2873.15
# A_M_type              big
# TemperatureF      5203.67
# Name: 2, dtype: object)
# (3, Temperature          2800
# L                  0.0002
# ...
